# %% [markdown]
# # Lecture 3: RecSys Algorithms and Pipeline
#
# ## Overview
#
# The goal of this assignment is to get you familiar with some recommender systems algorithms and apply them to a sample of the steam dataset.
# The dataset is provided as a parquet file in the `data/` directory of this repository.
# It is simply a subset of the `train_interactions.csv` file on blackboard where random users are dropped.
#
# You will first implement cosine similarity and the ItemKNN algorithm. Then, you will build a pipeline for lightGBM using the predictions from ItemKNN as candidates.
#
# Throughout this Jupyter Notebook, any code that requires your input or completion will be clearly marked with a Task and a [TODO] tag. Your job is to fill in these sections with the appropriate code, following the instructions and hints provided to guide you through each step.
#
# By the end of this task, you will have:
#
#    - Implemented cosine similarity
#    - Implemented the ItemKNN algorithm
#    - Evaluated the ItemKNN algorithm
#    - Implemented a recommender pipeline
#    - Generated and understood candidates
#    - Implemented some features
#    - Gotten to know LightGBM
#    - Evaluated your Hybrid model
#
# ## Setup
#
# We first import some libraries and define helper functions.

# %%
# import os
# os.chdir("/home/david/Desktop/recommenderSystems")


import scipy as sp
import numpy as np
import pandas as pd
from lightgbm import LGBMRanker
from recpack.matrix import InteractionMatrix
from recpack.scenarios import StrongGeneralization
from recpack.util import get_top_K_ranks
from src.metrics import calculate_ndcg, calculate_calibrated_recall
import warnings

warnings.simplefilter("ignore", sp.sparse.SparseEfficiencyWarning)


# helper function to turn a sparse matrix into a dataframe
def matrix2df(X) -> pd.DataFrame:
    coo = sp.sparse.coo_array(X)
    return pd.DataFrame({
        "user_id": coo.row,
        "item_id": coo.col,
        "value": coo.data
    })


# helper function to convert a score matrix into a dataframe of recommendations
def scores2recommendations(
    scores: sp.sparse.csr_matrix, 
    X_test_in: sp.sparse.csr_matrix, 
    recommendation_count: int,
    prevent_history_recos = True
) -> pd.DataFrame:
    # ensure you don't recommend fold-in items
    if prevent_history_recos:
        scores[(X_test_in > 0)] = 0
    # rank items
    ranks = get_top_K_ranks(scores, recommendation_count)
    # convert to a dataframe
    df_recos = matrix2df(ranks).rename(columns={"value": "rank"}).sort_values(["user_id", "rank"])
    return df_recos
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 12
#      10 from recpack.scenarios import StrongGeneralization
#      11 from recpack.util import get_top_K_ranks
# ---> 12 from src.metrics import calculate_ndcg, calculate_calibrated_recall
#      13 import warnings
#      15 warnings.simplefilter("ignore", sp.sparse.SparseEfficiencyWarning)
#
# ModuleNotFoundError: No module named 'src'

# %% [markdown]
# ### Dataset loading and splitting
#
# We start by loading in the sampled Steam dataset and splitting it using strong generalization.
# You should be familiar with strong generalization and dataset splitting from the previous assignment.
#
# For simplicity, we use the strong generalization scenario implementation from Recpack to get a train-test split, with 80% of the data being used for training and 20% for testing.
# As a reminding, strong generalization means that we don't have any overlap between the users of the test and training set.
# The test sets consists of a fold-in part (containing the history of the test users) and a hold-out part (containing the remaining "ground truth" interactions of those users).
#
# **The goal is to use the training data to create a model, give it the fold-in test data as input, and have it predict the hold-out interactions.**
#
# [An example](https://recpack.froomle.ai/generated/recpack.scenarios.StrongGeneralization.html#recpack.scenarios.StrongGeneralization) can be found in the documentation of recpack.

# %%
#print(os.path.abspath(os.getcwd()))
# load data from parquet file
df = pd.read_parquet("lectures/data/interactions.parquet", engine="fastparquet")

print(df.head())

# create a Recpack interaction matrix
X = InteractionMatrix(df, item_ix="item_id", user_ix="user_id")

# split matrix using strong generalization
# we use a fixed seed for reproducibility
scenario = StrongGeneralization(frac_users_train=0.8, frac_interactions_in=0.8, validation=False, seed=42)
scenario.split(X)

# get interaction matrices
X_train = scenario.full_training_data.values
X_test_in = scenario.test_data_in.values
X_test_out = scenario.test_data_out.values

# dataframe version of hold-out set to compute metrics later on
df_test_out = matrix2df(X_test_out)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 #print(os.path.abspath(os.getcwd()))
#       2 # load data from parquet file
# ----> 3 df = pd.read_parquet("lectures/data/interactions.parquet", engine="fastparquet")
#       5 print(df.head())
#       7 # create a Recpack interaction matrix
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ## Task 1: Implementing ItemKNN
#
# ### Objective
#
# Implement ItemKNN using cosine as similarity measure.
#
# ### Overview
#
# 1. We will first implement cosine similarity so we can calculate all pairwise item similarities from an interaction matrix
# 2. Next, we will implement ItemKNN to calculate scores for each (user, item) pair
# 3. Finally, we will generate recommendations based on the scores and calculate some evaluation metrics
#
# ### Background
#
# The ItemKNN algorithm consists of 3 main steps and makes recommendations based on the similarities between items.
#
# The first step is to define and implement a similarity measure between items. In this task we will use cosine similarity, but there exist many more. For those interested, additional similarities can be found in the slides and on the web. The second step is to find the k most similar neighbors for each item (i.e. prune the similarity matrix). The final step is to calculate a score for each (user, item) pair.
#
# ### Task 1.1: Cosine similarity
#
# Complete the function in the cell below to calculate all pairwise cosine similarities.
# Items should not be considered similar to themselves, so remember to set the diagonal to zero.
#
# The cosine similarity between two vectors $\bf{a}$ and $\bf{b}$ is given by:
#
# $$\cos\left(\bf{a},\bf{b}\right)=\dfrac{\bf{a}\cdot\bf{b}}{\| \bf{a}\|_2 \cdot \| \bf{b}\|_2 }=\dfrac{\sum_{i=0}^{n} a_i \cdot b_i}{\sqrt{\sum_{i=0}^{n} a_i^2} \cdot \sqrt{\sum_{i=0}^{n} b_i^2}}$$
#
# **Hint**: think about how you can compute this for all pairwise similarities at once.

# %%
def my_cosine_similarity(X: sp.sparse.csr_matrix) -> sp.sparse.csr_matrix:
    # TODO: implement cosine similarity function
    # hint: should return a sparse (item x item)-matrix
    # hint: work with the entire matrix to benefit from highly optimized vectorized operations in numpy and scipy
    # important: don't forget to set the diagonal to 0 (no self-similarity)

    dot_product = X.T.dot(X)

    norms = np.sqrt(X.power(2).sum(axis=0)).A1
    norms[norms == 0] = 1e-10  # avoid division by zero

    inv_norms = 1.0 / norms
    cosine_sim = dot_product.multiply(inv_norms).T.multiply(inv_norms).T

    cosine_sim.setdiag(0)

    # removing small values from the matrix
    cosine_sim.eliminate_zeros()
    cosine_sim.data[np.abs(cosine_sim.data) < 1e-12] = 0
    cosine_sim.eliminate_zeros()

    return cosine_sim.tocsr()


# check whether similarities match expected output
S = my_cosine_similarity(X_train)
assert sp.sparse.isspmatrix(S)
assert S.shape == (8523, 8523)
print(S.nnz)
assert S.nnz == 11817736
assert np.isclose(S[0, 0], 0)
assert np.isclose(S[0, 42], 0.1145873121273334)
assert np.isclose(S[42, 314], 0.06482037234831424)
# Out:
# 11817736

# %% [markdown]
# ### Task 1.2: Complete ItemKNN implementation
#
# Complete the `item_knn_scores` function in the cell below to calculate recommendation scores based on the ItemKNN algorithm.
# You should use the `get_top_K_values` function from [repack](https://gitlab.com/recpack-maintainers/recpack/-/blob/master/recpack/util.py?ref_type=heads#L80) to prune the similarities and keep only the k highest values for each row.
#
# The code below the function uses the scores to create a dataframe of recommendations.
# This dataframe is compared against the hold-out dataframe using NDCG and Recall as accuracy metrics.
#
# The expected outputs are:
#
# + NDCG@10: 0.26746
# + Recall@10: 0.27379
#
# Note that the results may differ due to non-determinism in `get_top_K_values` and `get_top_K_ranks`

# %%
from recpack.util import get_top_K_values

def item_knn_scores(
    X_train: sp.sparse.csr_matrix, 
    X_test_in: sp.sparse.csr_matrix, 
    neighbor_count: int
) -> sp.sparse.csr_matrix:
    # TODO: add code to compute scores for all (user, item) pairs
    # hint: use your own cosine similarity function
    # hint: use `get_top_K_values` to prune the similarity matrix
    # hint: think about how you can calculate the scores for all pairs at once
    S = my_cosine_similarity(X_train)

    top_k = get_top_K_values(S, neighbor_count)

    scores = X_test_in.dot(top_k)

    return scores

scores = item_knn_scores(X_train, X_test_in, 50)
df_recos = scores2recommendations(scores, X_test_in, 10)

ndcg = calculate_ndcg(df_recos, 10, df_test_out)
recall = calculate_calibrated_recall(df_recos, 10, df_test_out)

print(f"  NDCG@10: {ndcg:.5f}")
print(f"Recall@10: {recall:.5f}")
# Out:
#   NDCG@10: 0.26727
# Recall@10: 0.27367

# %% [markdown]
# ## Task 2: LightGBM Pipeline
#
# ### Objective
#
# Extend and use a recommendation pipeline that generates candidates, adds features and ranks the candidates.
#
# ### Overview
#
# 1. First, we generate candidates based on popularity and your itemKNN implementation
# 2. Next, we add the features from your previous assignment
# 3. Finally, we use LightGBMRanker to rank the candidates and evaluate the results
#
# ### Background
#
# You can read more about LightGBM and recommendation pipelines in [this](https://medium.com/@mohtasim.hossain2000/mastering-lightgbm-an-in-depth-guide-to-efficient-gradient-boosting-8bfeff15ee17) and [this](https://medium.com/data-science/building-a-recommender-system-using-machine-learning-2eefba9a692e) medium article.

# %% [markdown]
# ### Task 2.1: Candidate generation
#
# The first step is candidate generation.
#
# For the training candidates we start with all true interactions (positive examples), we then add the most popular items as extra candidates. Some of these popular item candidate will coincide with true interaction that we already added, this is not a problem and we just combine duplicates (automatic with `pd.merge`). Some other popular item candidates will not be true interaction and these become our negative examples.
#
# The LGBMRanker will use these positive en negative examples to learn a model that can rank candidates for which we don't know whether they are positive of negative: i.e. our test candidates.
#
# Our test candidates should be generated as similarly to our training candidates as possible. The major difference is that we do not include any interactions from the fold-in. After all, we know the fold-in and hold-out are disjoint.
#
# **Task**: Add candidates based on your ItemKNN implementation and include a feature indicating that the candidate originates from ItemKNN.
#
# #### Tips
#
# + Look at how the popularity candidates are generated for guidance
#     + The popularity candidates are the same for each user but your ItemKNN candidates will be personalized
#     + The popularity rank is added as a feature for the candidates, you can do something similar for your candidates
#     + The `pd.merge` operations will look nearly identical.
# + Use `scores2recommendations` to get a dataframe based on your ItemKNN scores
#     + For the training candidates, you don't want to remove repeat recommendation (`prevent_history_recos=False`)
# . Otherwise the model will learn that ItemKNN candidates are never relevant, which we don't want.
#     + For the test candidate you do want to remove repeat recommendation (`prevent_history_recos=True`)
# + Don't forget to adjust the `pd.fillna` at the end for your new feature.

# %%
def get_candidates_popularity(X_train, X_test_in, k=10):
    item_counts = X_train.sum(axis=0).A1
    top_items = np.argpartition(item_counts, -k)[-k:][::-1]

    train_users = np.where(X_train.sum(axis=1).A1)[0]
    test_users = np.where(X_test_in.sum(axis=1).A1)[0]

    df_candidates_train = pd.DataFrame(data={
        "user_id": train_users,
        "item_id": list(np.tile(top_items, (len(train_users), 1)))
    }).explode("item_id")

    df_candidates_test = pd.DataFrame(data={
        "user_id": test_users,
        "item_id": list(np.tile(top_items, (len(test_users), 1)))
    }).explode("item_id")
    
    df_candidates_train["popularity_rank"] = df_candidates_train.groupby("user_id").cumcount()
    df_candidates_test["popularity_rank"] = df_candidates_test.groupby("user_id").cumcount()

    return df_candidates_train, df_candidates_test

# generate candidates
df_train = matrix2df(X_train).rename(columns={"value": "played"})
df_test = pd.DataFrame(columns=["user_id", "item_id"], dtype=np.int64) # empty dataframe

# add popularity candidates
df_candidates_pop_train, df_candidates_pop_test = get_candidates_popularity(X_train, X_test_in, 10)
df_train = pd.merge(df_train, df_candidates_pop_train, how="outer", on=["user_id", "item_id"])
df_test = pd.merge(df_test, df_candidates_pop_test, how="outer", on=["user_id", "item_id"])

# add item knn candidates
df_candidates_knn_train = scores2recommendations(
    S, X_train, recommendation_count=10, prevent_history_recos=False
)

df_candidates_knn_test = scores2recommendations(
    S, X_test_in, recommendation_count=10, prevent_history_recos=False
)

df_train = pd.merge(df_train, df_candidates_knn_train, how="outer", on=["user_id", "item_id"])
df_test = pd.merge(df_test, df_candidates_knn_test, how="outer", on=["user_id", "item_id"])

df_candidates_knn_train["itemknn_rank"] = df_candidates_knn_train.groupby("user_id").cumcount()
df_candidates_knn_test["itemknn_rank"] = df_candidates_knn_test.groupby("user_id").cumcount()

# fill missing values
df_train.fillna({"played": 0, "popularity_rank": 999, "itemknn_rank": 999}, inplace=True)
df_test.fillna({"popularity_rank": 999, "itemknn_rank": 999}, inplace=True)

# %% [markdown]
# ### Task 2.2: Create features
#
# We now have our candidates, but we don't have any features except those related to the origin of the candidates. For our model to improve, we need to add content-based features related to the items and or users.
#
# **Task**:
#
# + Create 2 features to the candidates based on the previous assignments.
# + Add them to both `df_test` and `df_train`.
# + Explain your features too, explain why you think they might help to better rank the candidates.
#
# #### Example
#
# An example feature might be the price of the game. You will need to make sure to first preprocess and clean the price values because LightGBM can only handle numerical values (no strings or datetime objects). Once you have the price for each game, you can merge this data into your candidate dataframes (e.g. `pd.merge(df_train, df_item_price, on="item_id")`). Make sure add the features to both `df_test` and `df_train`.

# %%
df_games = pd.read_csv("data/games.csv")
df_games["price"].head()
df_games.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df_games = pd.read_csv("cleaned_datasets_students/games.csv")
#       2 df_games["price"].head()
#       3 df_games.head()
#
# File ~/Desktop/recommenderSystems/.venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/Desktop/recommenderSystems/.venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/Desktop/recommenderSystems/.venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/Desktop/recommenderSystems/.venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/Desktop/recommenderSystems/.venv/lib/python3.11/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'cleaned_datasets_students/games.csv'

# %%
df_extended_games = pd.read_csv("data/extended_games.csv")
df_extended_games.T.head(40)
# Out:
#                                                                        0     \
# item_id                                                                   0
# item_name                                                    Counter-Strike
# release_date                                                    Nov 1, 2000
# required_age                                                              0
# price                                                                  9.99
# dlc_count                                                                 0
# detailed_description      Play the world's number 1 online action game. ...
# about_the_game            Play the world's number 1 online action game. ...
# short_description         Play the world's number 1 online action game. ...
# reviews                                                                 NaN
# header_image              https://cdn.akamai.steamstatic.com/steam/apps/...
# website                                                                 NaN
# support_url                                http://steamcommunity.com/app/10
# support_email                                                           NaN
# windows                                                                True
# mac                                                                    True
# linux                                                                  True
# metacritic_score                                                         88
# metacritic_url            https://www.metacritic.com/game/pc/counter-str...
# achievements                                                              0
# recommendations                                                      122770
# notes                                  Includes intense violence and blood.
# supported_languages       ['English', 'French', 'German', 'Italian', 'Sp...
# full_audio_languages      ['English', 'French', 'German', 'Italian', 'Sp...
# packages                  [{'title': 'Buy Counter-Strike', 'description'...
# developers                                                        ['Valve']
# publishers                                                        ['Valve']
# categories                ['Multi-player', 'PvP', 'Online PvP', 'Shared/...
# genres                                                           ['Action']
# screenshots               ['https://cdn.akamai.steamstatic.com/steam/app...
# movies                                                                   []
# user_score                                                                0
# score_rank                                                              NaN
# positive                                                             198387
# negative                                                               5135
# estimated_owners                                        10000000 - 20000000
# average_playtime_forever                                              10524
# average_playtime_2weeks                                                1733
# median_playtime_forever                                                 228
# median_playtime_2weeks                                                  733
#
#                                                                        1     \
# item_id                                                                   1
# item_name                                                  Rag Doll Kung Fu
# release_date                                                   Oct 12, 2005
# required_age                                                              0
# price                                                                  0.99
# dlc_count                                                                 0
# detailed_description      A piece of Steam history - THE FIRST EVER NON ...
# about_the_game            A piece of Steam history - THE FIRST EVER NON ...
# short_description         A piece of Steam history - THE FIRST EVER NON ...
# reviews                                                                 NaN
# header_image              https://cdn.akamai.steamstatic.com/steam/apps/...
# website                                       http://www.ragdollkungfu.com/
# support_url                                                             NaN
# support_email                                                           NaN
# windows                                                                True
# mac                                                                   False
# linux                                                                 False
# metacritic_score                                                         69
# metacritic_url            https://www.metacritic.com/game/pc/rag-doll-ku...
# achievements                                                              0
# recommendations                                                           0
# notes                                                                   NaN
# supported_languages                                             ['English']
# full_audio_languages                                                     []
# packages                  [{'title': 'Buy Rag Doll Kung Fu', 'descriptio...
# developers                                                  ['Mark Healey']
# publishers                                                  ['Mark Healey']
# categories                                ['Single-player', 'Multi-player']
# genres                                                            ['Indie']
# screenshots               ['https://cdn.akamai.steamstatic.com/steam/app...
# movies                                                                   []
# user_score                                                                0
# score_rank                                                              NaN
# positive                                                                 55
# negative                                                                 23
# estimated_owners                                              20000 - 50000
# average_playtime_forever                                                 15
# average_playtime_2weeks                                                   0
# median_playtime_forever                                                  15
# median_playtime_2weeks                                                    0
#
#                                                                        2     \
# item_id                                                                   2
# item_name                                                            Silo 2
# release_date                                                   Dec 19, 2012
# required_age                                                              0
# price                                                                 59.99
# dlc_count                                                                 0
# detailed_description      Note: This is a legacy version of Silo which i...
# about_the_game            Note: This is a legacy version of Silo which i...
# short_description         Silo is a focused, lightning-fast standalone 3...
# reviews                                                                 NaN
# header_image              https://cdn.akamai.steamstatic.com/steam/apps/...
# website                                         http://nevercenter.com/silo
# support_url                    http://nevercenter.com/silo/?section=support
# support_email                                       support@nevercenter.com
# windows                                                                True
# mac                                                                    True
# linux                                                                 False
# metacritic_score                                                          0
# metacritic_url                                                          NaN
# achievements                                                              0
# recommendations                                                           0
# notes                                                                   NaN
# supported_languages                                             ['English']
# full_audio_languages                                                     []
# packages                  [{'title': 'Buy Silo 2', 'description': '', 's...
# developers                                         ['Nevercenter Ltd. Co.']
# publishers                                         ['Nevercenter Ltd. Co.']
# categories                                                               []
# genres                                             ['Animation & Modeling']
# screenshots               ['https://cdn.akamai.steamstatic.com/steam/app...
# movies                                                                   []
# user_score                                                                0
# score_rank                                                              NaN
# positive                                                                 57
# negative                                                                 25
# estimated_owners                                                  0 - 20000
# average_playtime_forever                                                  0
# average_playtime_2weeks                                                   0
# median_playtime_forever                                                   0
# median_playtime_2weeks                                                    0
#
#                                                                        3     \
# item_id                                                                   3
# item_name                                        Call of Duty: World at War
# release_date                                                   Nov 18, 2008
# required_age                                                             17
# price                                                                 19.99
# dlc_count                                                                 0
# detailed_description      Call of Duty is back, redefining war like you'...
# about_the_game            Call of Duty is back, redefining war like you'...
# short_description         Call of Duty is back, redefining war like you'...
# reviews                                                                 NaN
# header_image              https://cdn.akamai.steamstatic.com/steam/apps/...
# website                                           http://www.callofduty.com
# support_url                                  http://support.activision.com/
# support_email                                                           NaN
# windows                                                                True
# mac                                                                   False
# linux                                                                 False
# metacritic_score                                                         83
# metacritic_url            https://www.metacritic.com/game/pc/call-of-dut...
# achievements                                                              0
# recommendations                                                       35258
# notes                                                                   NaN
# supported_languages       ['English', 'French', 'Italian', 'German', 'Sp...
# full_audio_languages                                                     []
# packages                  [{'title': 'Buy Call of Duty: World at War', '...
# developers                                                     ['Treyarch']
# publishers                                                   ['Activision']
# categories                       ['Single-player', 'Multi-player', 'Co-op']
# genres                                                           ['Action']
# screenshots               ['https://cdn.akamai.steamstatic.com/steam/app...
# movies                    ['http://cdn.akamai.steamstatic.com/steam/apps...
# user_score                                                                0
# score_rank                                                              NaN
# positive                                                              38439
# negative                                                               3363
# estimated_owners                                          2000000 - 5000000
# average_playtime_forever                                               2558
# average_playtime_2weeks                                                  21
# median_playtime_forever                                                1002
# median_playtime_2weeks                                                   26
#
#                                                                        4     \
# item_id                                                                  13
# item_name                                               Runespell: Overture
# release_date                                                   Jul 20, 2011
# required_age                                                              0
# price                                                                  9.99
# dlc_count                                                                 0
# detailed_description      Runespell: Overture is a role-playing game com...
# about_the_game            Runespell: Overture is a role-playing game com...
# short_description         This role-playing game, set in an alternate me...
# reviews                                                                 NaN
# header_image              https://cdn.akamai.steamstatic.com/steam/apps/...
# website                                           http://www.runespell.com/
# support_url                          https://runespell.zendesk.com/hc/en-us
# support_email                                                           NaN
# windows                                                                True
# mac                                                                   False
# linux                                                                 False
# metacritic_score                                                         69
# metacritic_url            https://www.metacritic.com/game/pc/runespell-o...
# achievements                                                             35
# recommendations                                                         194
# notes                                                                   NaN
# supported_languages                                             ['English']
# full_audio_languages                                                     []
# packages                  [{'title': 'Buy Runespell: Overture', 'descrip...
# developers                                                   ['Mystic Box']
# publishers                                                   ['Mystic Box']
# categories                ['Single-player', 'Steam Achievements', 'Steam...
# genres                                        ['Adventure', 'Indie', 'RPG']
# screenshots               ['https://cdn.akamai.steamstatic.com/steam/app...
# movies                                                                   []
# user_score                                                                0
# score_rank                                                              NaN
# positive                                                                272
# negative                                                                 93
# estimated_owners                                             50000 - 100000
# average_playtime_forever                                                 72
# average_playtime_2weeks                                                   0
# median_playtime_forever                                                 117
# median_playtime_2weeks                                                    0
#
#                                                                        5     \
# item_id                                                                  14
# item_name                                          Dead Mountaineer's Hotel
# release_date                                                   Oct 28, 2011
# required_age                                                              0
# price                                                                  7.99
# dlc_count                                                                 0
# detailed_description      The remote hotel stands atop an ominous snow-p...
# about_the_game            The remote hotel stands atop an ominous snow-p...
# short_description         The remote hotel stands atop an ominous snow-p...
# reviews                                                                 NaN
# header_image              https://cdn.akamai.steamstatic.com/steam/apps/...
# website                                            http://hotel.akella.com/
# support_url                                              support@akella.com
# support_email                                                           NaN
# windows                                                                True
# mac                                                                   False
# linux                                                                 False
# metacritic_score                                                          0
# metacritic_url                                                          NaN
# achievements                                                              0
# recommendations                                                           0
# notes                                                                   NaN
# supported_languages                        ['English', 'German', 'Russian']
# full_audio_languages                                                     []
# packages                  [{'title': "Buy Dead Mountaineer's Hotel", 'de...
# developers                                          ['Electronic Paradise']
# publishers                                                       ['Akella']
# categories                                                ['Single-player']
# genres                                                        ['Adventure']
# screenshots               ['https://cdn.akamai.steamstatic.com/steam/app...
# movies                                                                   []
# user_score                                                                0
# score_rank                                                              NaN
# positive                                                                 35
# negative                                                                 66
# estimated_owners                                              20000 - 50000
# average_playtime_forever                                                  0
# average_playtime_2weeks                                                   0
# median_playtime_forever                                                   0
# median_playtime_2weeks                                                    0
#
#                                                                        6     \
# item_id                                                                  16
# item_name                                                  Vertex Dispenser
# release_date                                                   Jun 10, 2011
# required_age                                                              0
# price                                                                  9.99
# dlc_count                                                                 0
# detailed_description      Vertex Dispenser is an abstract real-time stra...
# about_the_game            Vertex Dispenser is an abstract real-time stra...
# short_description                                    #app_102400_short_desc
# reviews                                                                 NaN
# header_image              https://cdn.akamai.steamstatic.com/steam/apps/...
# website                                     http://www.vertexdispenser.com/
# support_url                                                             NaN
# support_email                                            smestorp@gmail.com
# windows                                                                True
# mac                                                                    True
# linux                                                                 False
# metacritic_score                                                         70
# metacritic_url            https://www.metacritic.com/game/pc/vertex-disp...
# achievements                                                             12
# recommendations                                                           0
# notes                                                                   NaN
# supported_languages                                             ['English']
# full_audio_languages                                                     []
# packages                  [{'title': 'Buy Vertex Dispenser', 'descriptio...
# developers                                               ['Michael Brough']
# publishers                                               ['Michael Brough']
# categories                ['Single-player', 'Multi-player', 'Co-op', 'Cr...
# genres                                      ['Action', 'Indie', 'Strategy']
# screenshots               ['https://cdn.akamai.steamstatic.com/steam/app...
# movies                                                                   []
# user_score                                                                0
# score_rank                                                              NaN
# positive                                                                 22
# negative                                                                  9
# estimated_owners                                                  0 - 20000
# average_playtime_forever                                                 20
# average_playtime_2weeks                                                   0
# median_playtime_forever                                                  20
# median_playtime_2weeks                                                    0
#
#                                                                        7     \
# item_id                                                                  17
# item_name                                      PT Boats: Knights of the Sea
# release_date                                                   Oct 28, 2011
# required_age                                                              0
# price                                                                  6.99
# dlc_count                                                                 0
# detailed_description      PT Boats is dedicated to a small group of litt...
# about_the_game            PT Boats is dedicated to a small group of litt...
# short_description         PT Boats is dedicated to a small group of litt...
# reviews                                                                 NaN
# header_image              https://cdn.akamai.steamstatic.com/steam/apps/...
# website                                         http://pt-boats.akella.com/
# support_url                                                             NaN
# support_email                                                           NaN
# windows                                                                True
# mac                                                                   False
# linux                                                                 False
# metacritic_score                                                          0
# metacritic_url                                                          NaN
# achievements                                                              0
# recommendations                                                           0
# notes                                                                   NaN
# supported_languages                                             ['English']
# full_audio_languages                                                     []
# packages                  [{'title': 'Buy PT Boats: Knights of the Sea',...
# developers                                                      ['Studio4']
# publishers                                                       ['Akella']
# categories                                ['Single-player', 'Multi-player']
# genres                                                       ['Simulation']
# screenshots               ['https://cdn.akamai.steamstatic.com/steam/app...
# movies                                                                   []
# user_score                                                                0
# score_rank                                                              NaN
# positive                                                                 19
# negative                                                                 19
# estimated_owners                                                  0 - 20000
# average_playtime_forever                                                  0
# average_playtime_2weeks                                                   0
# median_playtime_forever                                                   0
# median_playtime_2weeks                                                    0
#
#                                                                        8     \
# item_id                                                                  19
# item_name                                            PT Boats: South Gambit
# release_date                                                   Oct 28, 2011
# required_age                                                              0
# price                                                                  6.99
# dlc_count                                                                 0
# detailed_description      “The seas can be dangerous, but when you’re in...
# about_the_game            “The seas can be dangerous, but when you’re in...
# short_description         “The seas can be dangerous, but when you’re in...
# reviews                                                                 NaN
# header_image              https://cdn.akamai.steamstatic.com/steam/apps/...
# website                                http://en.akella.com/Game.aspx?id=48
# support_url                                                             NaN
# support_email                                                           NaN
# windows                                                                True
# mac                                                                   False
# linux                                                                 False
# metacritic_score                                                          0
# metacritic_url                                                          NaN
# achievements                                                              0
# recommendations                                                           0
# notes                                                                   NaN
# supported_languages                                             ['English']
# full_audio_languages                                                     []
# packages                  [{'title': 'Buy PT Boats: South Gambit', 'desc...
# developers                                                      ['studio4']
# publishers                                                       ['Akella']
# categories                                ['Single-player', 'Multi-player']
# genres                                                       ['Simulation']
# screenshots               ['https://cdn.akamai.steamstatic.com/steam/app...
# movies                                                                   []
# user_score                                                                0
# score_rank                                                              NaN
# positive                                                                 12
# negative                                                                 13
# estimated_owners                                                  0 - 20000
# average_playtime_forever                                                  0
# average_playtime_2weeks                                                   0
# median_playtime_forever                                                   0
# median_playtime_2weeks                                                    0
#
#                                                                        9     \
# item_id                                                                  20
# item_name                                                    Orcs Must Die!
# release_date                                                   Oct 11, 2011
# required_age                                                              0
# price                                                                  9.99
# dlc_count                                                                 2
# detailed_description      Slice them, burn them, skewer them, and launch...
# about_the_game            Slice them, burn them, skewer them, and launch...
# short_description         Slice them, burn them, skewer them, and launch...
# reviews                   “Not since Lemmings has a game so seamlessly m...
# header_image              https://cdn.akamai.steamstatic.com/steam/apps/...
# website                          https://robotentertainment.com/omd-details
# support_url                           https://orcsmustdie.com/#!/en/support
# support_email                                                           NaN
# windows                                                                True
# mac                                                                   False
# linux                                                                 False
# metacritic_score                                                         83
# metacritic_url            https://www.metacritic.com/game/pc/orcs-must-d...
# achievements                                                             27
# recommendations                                                        5406
# notes                                                                   NaN
# supported_languages       ['English', 'German', 'French', 'Italian', 'Sp...
# full_audio_languages      ['English', 'German', 'French', 'Italian', 'Sp...
# packages                  [{'title': 'Buy Orcs Must Die!', 'description'...
# developers                                          ['Robot Entertainment']
# publishers                                          ['Robot Entertainment']
# categories                ['Single-player', 'Steam Achievements', 'Parti...
# genres                                      ['Action', 'Indie', 'Strategy']
# screenshots               ['https://cdn.akamai.steamstatic.com/steam/app...
# movies                    ['http://cdn.akamai.steamstatic.com/steam/apps...
# user_score                                                                0
# score_rank                                                              NaN
# positive                                                               6779
# negative                                                                251
# estimated_owners                                          1000000 - 2000000
# average_playtime_forever                                                373
# average_playtime_2weeks                                                   0
# median_playtime_forever                                                 240
# median_playtime_2weeks                                                    0
#
#                           ...  \
# item_id                   ...
# item_name                 ...
# release_date              ...
# required_age              ...
# price                     ...
# dlc_count                 ...
# detailed_description      ...
# about_the_game            ...
# short_description         ...
# reviews                   ...
# header_image              ...
# website                   ...
# support_url               ...
# support_email             ...
# windows                   ...
# mac                       ...
# linux                     ...
# metacritic_score          ...
# metacritic_url            ...
# achievements              ...
# recommendations           ...
# notes                     ...
# supported_languages       ...
# full_audio_languages      ...
# packages                  ...
# developers                ...
# publishers                ...
# categories                ...
# genres                    ...
# screenshots               ...
# movies                    ...
# user_score                ...
# score_rank                ...
# positive                  ...
# negative                  ...
# estimated_owners          ...
# average_playtime_forever  ...
# average_playtime_2weeks   ...
# median_playtime_forever   ...
# median_playtime_2weeks    ...
#
#                                                                        6743  \
# item_id                                                                8510
# item_name                                                     Yar's Revenge
# release_date                                                   Apr 28, 2011
# required_age                                                              0
# price                                                                  9.99
# dlc_count                                                                 0
# detailed_description      In Yar’s Revenge, take flight as you explore e...
# about_the_game            In Yar’s Revenge, take flight as you explore e...
# short_description         Take flight as you explore exotic alien worlds...
# reviews                                                                 NaN
# header_image              https://cdn.akamai.steamstatic.com/steam/apps/...
# website                                    http://www.atari.com/yarsrevenge
# support_url                                                             NaN
# support_email                                                           NaN
# windows                                                                True
# mac                                                                   False
# linux                                                                 False
# metacritic_score                                                         56
# metacritic_url            https://www.metacritic.com/game/pc/yars-reveng...
# achievements                                                             12
# recommendations                                                           0
# notes                                                                   NaN
# supported_languages                         ['English', 'French', 'German']
# full_audio_languages                                                     []
# packages                  [{'title': "Buy Yar's Revenge", 'description':...
# developers                                      ['Killspace Entertainment']
# publishers                                                        ['Atari']
# categories                ['Single-player', 'Multi-player', 'Shared/Spli...
# genres                                                           ['Action']
# screenshots               ['https://cdn.akamai.steamstatic.com/steam/app...
# movies                                                                   []
# user_score                                                                0
# score_rank                                                              NaN
# positive                                                                 42
# negative                                                                 25
# estimated_owners                                                  0 - 20000
# average_playtime_forever                                                 18
# average_playtime_2weeks                                                   0
# median_playtime_forever                                                  18
# median_playtime_2weeks                                                    0
#
#                                                                        6744  \
# item_id                                                                8513
# item_name                                                      Renegade Ops
# release_date                                                   Oct 26, 2011
# required_age                                                              0
# price                                                                  15.0
# dlc_count                                                                 2
# detailed_description      Destruction just got awesome. In Renegade Ops ...
# about_the_game            Destruction just got awesome. In Renegade Ops ...
# short_description         Blast your way through enemy lines to defeat I...
# reviews                                                                 NaN
# header_image              https://cdn.akamai.steamstatic.com/steam/apps/...
# website                      http://www.sega.co.uk/renegadeops/?t=EnglishUK
# support_url                                      https://support.sega.co.uk
# support_email                                                           NaN
# windows                                                                True
# mac                                                                   False
# linux                                                                 False
# metacritic_score                                                         76
# metacritic_url            https://www.metacritic.com/game/pc/renegade-op...
# achievements                                                             16
# recommendations                                                         778
# notes                                                                   NaN
# supported_languages       ['English', 'French', 'German', 'Italian', 'Sp...
# full_audio_languages                                                     []
# packages                  [{'title': 'Buy Renegade Ops', 'description': ...
# developers                                            ['Avalanche Studios']
# publishers                                                         ['SEGA']
# categories                ['Single-player', 'Multi-player', 'Co-op', 'Sh...
# genres                                                           ['Action']
# screenshots               ['https://cdn.akamai.steamstatic.com/steam/app...
# movies                                                                   []
# user_score                                                                0
# score_rank                                                              NaN
# positive                                                               2151
# negative                                                                373
# estimated_owners                                           500000 - 1000000
# average_playtime_forever                                                 93
# average_playtime_2weeks                                                   0
# median_playtime_forever                                                 121
# median_playtime_2weeks                                                    0
#
#                                                                        6745  \
# item_id                                                                8514
# item_name                                                      Blade Kitten
# release_date                                                   May 22, 2014
# required_age                                                              0
# price                                                                  2.99
# dlc_count                                                                 3
# detailed_description      The Hollow Wish Collection Only available here...
# about_the_game            The Hollow Wish Collection Only available here...
# short_description         In Blade Kitten, join Kit Ballard as she explo...
# reviews                   “Luxuriating in lavish production values and s...
# header_image              https://cdn.akamai.steamstatic.com/steam/apps/...
# website                                          http://www.bladekitten.com
# support_url                         http://www.bladekitten.com/support.html
# support_email                                      support@kromestudios.com
# windows                                                                True
# mac                                                                   False
# linux                                                                 False
# metacritic_score                                                         52
# metacritic_url            https://www.metacritic.com/game/pc/blade-kitte...
# achievements                                                             20
# recommendations                                                         842
# notes                                                                   NaN
# supported_languages       ['English', 'French', 'German', 'Italian', 'Sp...
# full_audio_languages                         ['English', 'Spanish - Spain']
# packages                  [{'title': 'Buy Blade Kitten', 'description': ...
# developers                                                ['Krome Studios']
# publishers                                                ['Krome Studios']
# categories                ['Single-player', 'Steam Achievements', 'Steam...
# genres                                              ['Action', 'Adventure']
# screenshots               ['https://cdn.akamai.steamstatic.com/steam/app...
# movies                    ['http://cdn.akamai.steamstatic.com/steam/apps...
# user_score                                                                0
# score_rank                                                              NaN
# positive                                                                830
# negative                                                                176
# estimated_owners                                            100000 - 200000
# average_playtime_forever                                                166
# average_playtime_2weeks                                                   0
# median_playtime_forever                                                 195
# median_playtime_2weeks                                                    0
#
#                                                                        6746  \
# item_id                                                                8515
# item_name                                      Garshasp: The Monster Slayer
# release_date                                                    May 9, 2011
# required_age                                                              0
# price                                                                  4.99
# dlc_count                                                                 0
# detailed_description      Years after the confinement of Azhi Dahaka by ...
# about_the_game            Years after the confinement of Azhi Dahaka by ...
# short_description         As the legendary Persian hero, fight your way ...
# reviews                                                                 NaN
# header_image              https://cdn.akamai.steamstatic.com/steam/apps/...
# website                                                 http://garshasp.com
# support_url                                             http://garshasp.com
# support_email                                          support@garshasp.com
# windows                                                                True
# mac                                                                   False
# linux                                                                 False
# metacritic_score                                                         49
# metacritic_url            https://www.metacritic.com/game/pc/garshasp-th...
# achievements                                                             36
# recommendations                                                         217
# notes                                                                   NaN
# supported_languages              ['English', 'German', 'Polish', 'Russian']
# full_audio_languages             ['English', 'German', 'Polish', 'Russian']
# packages                  [{'title': 'Buy Garshasp: The Monster Slayer',...
# developers                                                    ['Dead Mage']
# publishers                                               ['Digital Dragon']
# categories                ['Single-player', 'Steam Achievements', 'Parti...
# genres                                                  ['Action', 'Indie']
# screenshots               ['https://cdn.akamai.steamstatic.com/steam/app...
# movies                                                                   []
# user_score                                                                0
# score_rank                                                              NaN
# positive                                                                171
# negative                                                                183
# estimated_owners                                             50000 - 100000
# average_playtime_forever                                                  0
# average_playtime_2weeks                                                   0
# median_playtime_forever                                                   0
# median_playtime_2weeks                                                    0
#
#                                                                        6747  \
# item_id                                                                8516
# item_name                                    Garshasp: Temple of the Dragon
# release_date                                                   Sep 24, 2012
# required_age                                                              0
# price                                                                  4.99
# dlc_count                                                                 0
# detailed_description      The mighty mythological hero, Garshasp, travel...
# about_the_game            The mighty mythological hero, Garshasp, travel...
# short_description         The mighty mythological hero, Garshasp, travel...
# reviews                                                                 NaN
# header_image              https://cdn.akamai.steamstatic.com/steam/apps/...
# website                                                 http://garshasp.com
# support_url                                             http://garshasp.com
# support_email                                          support@garshasp.com
# windows                                                                True
# ...
# release_date                                                   Oct 12, 2023
# required_age                                                              0
# price                                                                 19.99
# dlc_count                                                                 0
# detailed_description      Chills and stealthy thrills abound In Haunted ...
# about_the_game            Chills and stealthy thrills abound In Haunted ...
# short_description         Creep, sneak, and dash your way through hordes...
# reviews                                                                 NaN
# header_image              https://cdn.akamai.steamstatic.com/steam/apps/...
# website                            https://atari.com/products/haunted-house
# support_url                                 https://atari.com/pages/contact
# support_email                                                           NaN
# windows                                                                True
# mac                                                                   False
# linux                                                                 False
# metacritic_score                                                          0
# metacritic_url                                                          NaN
# achievements                                                             25
# recommendations                                                           0
# notes                                                                   NaN
# supported_languages       ['English', 'German', 'Spanish - Spain', 'Port...
# full_audio_languages                                                     []
# packages                  [{'title': 'Buy Haunted House', 'description':...
# developers                                                 ['Orbit Studio']
# publishers                                                        ['Atari']
# categories                ['Single-player', 'Steam Achievements', 'Full ...
# genres                                              ['Action', 'Adventure']
# screenshots               ['https://cdn.akamai.steamstatic.com/steam/app...
# movies                    ['http://cdn.akamai.steamstatic.com/steam/apps...
# user_score                                                                0
# score_rank                                                              NaN
# positive                                                                 12
# negative                                                                  2
# estimated_owners                                                  0 - 20000
# average_playtime_forever                                                  0
# average_playtime_2weeks                                                   0
# median_playtime_forever                                                   0
# median_playtime_2weeks                                                    0
#
#                                                                        6749  \
# item_id                                                                8519
# item_name                                                          NightSky
# release_date                                                    Mar 1, 2011
# required_age                                                              0
# price                                                                  9.99
# dlc_count                                                                 0
# detailed_description      Nominated as a IGF Seamus McNally Finalist, Ni...
# about_the_game            Nominated as a IGF Seamus McNally Finalist, Ni...
# short_description         Nominated as a IGF Seamus McNally Finalist, Ni...
# reviews                                                                 NaN
# header_image              https://cdn.akamai.steamstatic.com/steam/apps/...
# website                                             http://www.nicalis.com/
# support_url                                                 www.nicalis.com
# support_email                                           support@nicalis.com
# windows                                                                True
# mac                                                                    True
# linux                                                                  True
# metacritic_score                                                         78
# metacritic_url            https://www.metacritic.com/game/pc/nightsky?ft...
# achievements                                                             22
# recommendations                                                         263
# notes                                                                   NaN
# supported_languages                                             ['English']
# full_audio_languages                                                     []
# packages                  [{'title': 'Buy NightSky', 'description': '', ...
# developers                                                ['Nicalis, Inc.']
# publishers                                                ['Nicalis, Inc.']
# categories                                                ['Single-player']
# genres                                      ['Casual', 'Indie', 'Strategy']
# screenshots               ['https://cdn.akamai.steamstatic.com/steam/app...
# movies                                                                   []
# user_score                                                                0
# score_rank                                                              NaN
# positive                                                                821
# negative                                                                112
# estimated_owners                                            200000 - 500000
# average_playtime_forever                                                 47
# average_playtime_2weeks                                                   0
# median_playtime_forever                                                  34
# median_playtime_2weeks                                                    0
#
#                                                                        6750  \
# item_id                                                                8520
# item_name                                                   The UnderGarden
# release_date                                                   Nov 10, 2010
# required_age                                                              0
# price                                                                  1.39
# dlc_count                                                                 0
# detailed_description      The UnderGarden is a casual Zen game that chal...
# about_the_game            The UnderGarden is a casual Zen game that chal...
# short_description         The UnderGarden is a casual Zen game that chal...
# reviews                   “UnderGarden could be one of this generation's...
# header_image              https://cdn.akamai.steamstatic.com/steam/apps/...
# website                                             http://www.retroism.com
# support_url                                                             NaN
# support_email                                                           NaN
# windows                                                                True
# mac                                                                   False
# linux                                                                 False
# metacritic_score                                                         67
# metacritic_url            https://www.metacritic.com/game/pc/the-underga...
# achievements                                                              0
# recommendations                                                           0
# notes                                                                   NaN
# supported_languages                         ['English', 'French', 'German']
# full_audio_languages                                                     []
# packages                  [{'title': 'Buy The UnderGarden', 'description...
# developers                                               ['Artech Studios']
# publishers                                                     ['Retroism']
# categories                                                ['Single-player']
# genres                                                           ['Casual']
# screenshots               ['https://cdn.akamai.steamstatic.com/steam/app...
# movies                                                                   []
# user_score                                                                0
# score_rank                                                              NaN
# positive                                                                 54
# negative                                                                 29
# estimated_owners                                              20000 - 50000
# average_playtime_forever                                                 21
# average_playtime_2weeks                                                   0
# median_playtime_forever                                                  21
# median_playtime_2weeks                                                    0
#
#                                                                        6751  \
# item_id                                                                8521
# item_name                                                    Spiral Knights
# release_date                                                   Jun 14, 2011
# required_age                                                              0
# price                                                                   0.0
# dlc_count                                                                 1
# detailed_description      Band together and fight to the Core! Spiral Kn...
# about_the_game            Band together and fight to the Core! Spiral Kn...
# short_description         Join the ranks of the Spiral Knights. Stranded...
# reviews                                                                 NaN
# header_image              https://cdn.akamai.steamstatic.com/steam/apps/...
# website                                       http://www.spiralknights.com/
# support_url                    http://wiki.spiralknights.com/Support_Portal
# support_email                                     support@spiralknights.com
# windows                                                                True
# mac                                                                    True
# linux                                                                 False
# metacritic_score                                                         64
# metacritic_url            https://www.metacritic.com/game/pc/spiral-knig...
# achievements                                                             54
# recommendations                                                         191
# notes                                                                   NaN
# supported_languages       ['English', 'French', 'German', 'Spanish - Spa...
# full_audio_languages                                                     []
# packages                  [{'title': 'Buy Spiral Knights', 'description'...
# developers                                                  ['Grey Havens']
# publishers                                                  ['Grey Havens']
# categories                ['Single-player', 'Multi-player', 'MMO', 'Co-o...
# genres                    ['Action', 'Adventure', 'Casual', 'Free to Pla...
# screenshots               ['https://cdn.akamai.steamstatic.com/steam/app...
# movies                    ['http://cdn.akamai.steamstatic.com/steam/apps...
# user_score                                                                0
# score_rank                                                              NaN
# positive                                                              18888
# negative                                                               3617
# estimated_owners                                          2000000 - 5000000
# average_playtime_forever                                               2035
# average_playtime_2weeks                                                   0
# median_playtime_forever                                                  92
# median_playtime_2weeks                                                    0
#
#                                                                        6752
# item_id                                                                8522
# item_name                                                    Puzzle Pirates
# release_date                                                   Aug 31, 2011
# required_age                                                              0
# price                                                                   0.0
# dlc_count                                                                 0
# detailed_description      Brace yourself for swashbuckling puzzle action...
# about_the_game            Brace yourself for swashbuckling puzzle action...
# short_description         Every activity in Puzzle Pirates is a uniquely...
# reviews                                                                 NaN
# header_image              https://cdn.akamai.steamstatic.com/steam/apps/...
# website                                        http://www.puzzlepirates.com
# support_url                           http://www.puzzlepirates.com/support/
# support_email                                     support@puzzlepirates.com
# windows                                                                True
# mac                                                                    True
# linux                                                                 False
# metacritic_score                                                          0
# metacritic_url                                                          NaN
# achievements                                                            220
# recommendations                                                           0
# notes                                                                   NaN
# supported_languages                ['English', 'German', 'Spanish - Spain']
# full_audio_languages                                                     []
# packages                                                                 []
# developers                                                  ['Grey Havens']
# publishers                                                  ['Grey Havens']
# categories                ['Single-player', 'Multi-player', 'MMO', 'PvP'...
# genres                    ['Adventure', 'Casual', 'Free to Play', 'Massi...
# screenshots               ['https://cdn.akamai.steamstatic.com/steam/app...
# movies                                                                   []
# user_score                                                                0
# score_rank                                                              NaN
# positive                                                               1394
# negative                                                                340
# estimated_owners                                            200000 - 500000
# average_playtime_forever                                                360
# average_playtime_2weeks                                                   0
# median_playtime_forever                                                 540
# median_playtime_2weeks                                                    0
#
# [40 rows x 6753 columns]

# %%
# add two features to df_train and df_test
df_extended_games['positive_ratings_ratio'] = df_extended_games['positive'] / (df_extended_games['positive'] + df_extended_games['negative'])
df_extended_games['positive_ratings_ratio'].head(50)

df_train = pd.merge(df_train, df_extended_games[['item_id', 'positive_ratings_ratio']], left_on='item_id', right_on='item_id', how='left')
df_test = pd.merge(df_test, df_extended_games[['item_id', 'positive_ratings_ratio']], left_on='item_id', right_on='item_id', how='left')

print(df_train.columns)
# Out:
# Index(['user_id', 'item_id', 'played', 'popularity_rank', 'rank',
#        'positive_ratings_ratio_x', 'price', 'positive_ratings_ratio_y'],
#       dtype='object')

# %%
# Data preprocessing: replacing the Free, Try this for Free, etc. values with 0
non_numeric_prices = df_games[~df_games['price'].astype(str).str.replace('.', '', 1).str.isdigit()]
non_numeric_prices['price'].unique()
# we can convert it to a 0
df_games['price'] = df_games['price'].replace(non_numeric_prices['price'].unique(), '0')
# Let's also convert the Nan value to 0
df_games['price'] = pd.to_numeric(df_games['price'], errors='coerce').fillna(0)

df_train = pd.merge(df_train, df_games[['item_id', 'price']], left_on='item_id', right_on='item_id', how='left')
df_test = pd.merge(df_test, df_games[['item_id', 'price']], left_on='item_id', right_on='item_id', how='left')

# %% [markdown]
# Your features should be new columns in the candidate dataframes. The columns of both dataframes should match except for `df_test` which doesn't have the `played` column.

# %%
print(df_train.columns)
print(df_test.columns)
# Out:
# Index(['user_id', 'item_id', 'played', 'popularity_rank', 'rank',
#        'positive_ratings_ratio', 'price'],
#       dtype='object')
# Index(['user_id', 'item_id', 'popularity_rank', 'rank',
#        'positive_ratings_ratio', 'price'],
#       dtype='object')

# %% [markdown]
# ### Task 2.3: Ranking
#
# The template below is almost completely filled in, you just need to specify which columns to use as features.
#
# You should not include `user_id`, `item_id` or `played` as features.
#
# The output shows the importance of features and the NDCG and Recall of the final recommendations.
#
# Did your features improve the recommendations? Feel free to play around with the pipeline and see if you can further improve the results. Try adding more candidates or changing the parameters of the lightGBM model.

# %%
feature_cols = ["price", "popularity_rank", "rank", "positive_ratings_ratio"]

# define ranker with sensible default parameters
ranker = LGBMRanker(
    force_row_wise=True,
    objective="lambdarank",
    metric="ndcg",
    boosting_type="dart",
    n_estimators=100,
    importance_type='gain',
)

# specify which records belong together
df_train = df_train.sort_values("user_id")
train_groups = df_train.groupby("user_id")["item_id"].count().to_list()

# fit ranker
ranker.fit(
    df_train[feature_cols], df_train["played"],
    group=train_groups
)

# generate final recommendations
df_test["score"] = ranker.predict(df_test[feature_cols])
df_recos = df_test.sort_values(["user_id", "score"], ascending=[True, False])

# evaluate recommendations
ndcg = calculate_ndcg(df_recos, 10, df_test_out)
recall = calculate_calibrated_recall(df_recos, 10, df_test_out)

# print results
print("------------------")
print(f"  NDCG@10: {ndcg:.5f}")
print(f"Recall@10: {recall:.5f}")

# print feature importance
for i in ranker.feature_importances_.argsort()[::-1]:
    imp = ranker.feature_importances_[i] / ranker.feature_importances_.sum()
    print(f"{feature_cols[i]:>30} {imp:.5f}")
# Out:
# [LightGBM] [Info] Total Bins 343
# [LightGBM] [Info] Number of data points in the train set: 418353, number of used features: 4
# ------------------
#   NDCG@10: 0.15730
# Recall@10: 0.18627
#                popularity_rank 0.72412
#                           rank 0.24459
#         positive_ratings_ratio 0.02639
#                          price 0.00491

# %% [markdown]
# ## Congratulations! You’ve completed the assignment.
